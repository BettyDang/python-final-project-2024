# %%
# Cell 1: Data Fetching
# This cell will fetch data from X
# (Add your code or pseudocode here)
# Cell 2: Data Processing
# This cell will process the data we got from X
# (Add your code or pseudocode here)

# %%
pokedex = {
    'Bulbasaur': {
        "Status":['HP:45', 'Attack:49', 'Defense:49', 'Speed:45'],
        "Skills":['Tackle', 'Leech Seed', 'Vine Whip'],
        "ID":['#001'],
        "Type":['Grass'],
        "Others":['Images/001.png', 'Background color:']
    },
    'Ivysaur': {
        "Status": ['HP:60', 'Attack:62', 'Defense:63', 'Speed:60'],
        "Skills": ['Tackle', 'Vine Whip', 'Razor Leaf'],
        "ID": ['#002'],
        "Type": ['Grass', 'Poison'],
        "Others": ['Images/002.png', 'Background color: Green']
    },
    'Venusaur': {
        "Status": ['HP:80', 'Attack:82', 'Defense:83', 'Speed:80'],
        "Skills": ['Vine Whip', 'Solar Beam', 'Sleep Powder'],
        "ID": ['#003'],
        "Type": ['Grass', 'Poison'],
        "Others": ['Images/003.png', 'Background color: Dark Green']
    },
    'Charmander': {
        "Status": ['HP:39', 'Attack:52', 'Defense:43', 'Speed:65'],
        "Skills": ['Scratch', 'Ember', 'Flamethrower'],
        "ID": ['#004'],
        "Type": ['Fire'],
        "Others": ['Images/004.png', 'Background color: Orange']
    },
    'Charmeleon': {
        "Status": ['HP:58', 'Attack:64', 'Defense:58', 'Speed:80'],
        "Skills": ['Flame Burst', 'Dragon Claw', 'Fire Fang'],
        "ID": ['#005'],
        "Type": ['Fire'],
        "Others": ['Images/005.png', 'Background color: Red']
    },
    'Charizard': {
        "Status": ['HP:78', 'Attack:84', 'Defense:78', 'Speed:100'],
        "Skills": ['Flamethrower', 'Fly', 'Dragon Claw'],
        "ID": ['#006'],
        "Type": ['Fire', 'Flying'],
        "Others": ['Images/006.png', 'Background color: Fiery Red']
    },
    'Squirtle': {
        "Status": ['HP:44', 'Attack:48', 'Defense:65', 'Speed:43'],
        "Skills": ['Water Gun', 'Bubble', 'Tackle'],
        "ID": ['#007'],
        "Type": ['Water'],
        "Others": ['Images/007.png', 'Background color: Blue']
    },
    'Wartortle': {
        "Status": ['HP:59', 'Attack:63', 'Defense:80', 'Speed:58'],
        "Skills": ['Water Pulse', 'Aqua Tail', 'Bite'],
        "ID": ['#008'],
        "Type": ['Water'],
        "Others": ['Images/008.png', 'Background color: Dark Blue']
    },
    'Blastoise': {
        "Status": ['HP:79', 'Attack:83', 'Defense:100', 'Speed:78'],
        "Skills": ['Hydro Pump', 'Skull Bash', 'Ice Beam'],
        "ID": ['#009'],
        "Type": ['Water'],
        "Others": ['Images/009.png', 'Background color: Deep Blue']
    },
    'Caterpie': {
        "Status": ['HP:45', 'Attack:30', 'Defense:35', 'Speed:45'],
        "Skills": ['Tackle', 'String Shot', 'Bug Bite'],
        "ID": ['#010'],
        "Type": ['Bug'],
        "Others": ['Images/010.png', 'Background color: Green']
    },
    'Metapod': {
        "Status": ['HP:50', 'Attack:20', 'Defense:55', 'Speed:30'],
        "Skills": ['Harden'],
        "ID": ['#011'],
        "Type": ['Bug'],
        "Others": ['Images/011.png', 'Background color: Light Green']
    },
    'Butterfree': {
        "Status": ['HP:60', 'Attack:45', 'Defense:50', 'Speed:70'],
        "Skills": ['Gust', 'Confusion', 'Sleep Powder'],
        "ID": ['#012'],
        "Type": ['Bug', 'Flying'],
        "Others": ['Images/012.png', 'Background color: Purple']
    },
    'Weedle': {
        "Status": ['HP:40', 'Attack:35', 'Defense:30', 'Speed:50'],
        "Skills": ['Poison Sting', 'String Shot', 'Bug Bite'],
        "ID": ['#013'],
        "Type": ['Bug', 'Poison'],
        "Others": ['Images/013.png', 'Background color: Yellow']
    },
    'Kakuna': {
        "Status": ['HP:45', 'Attack:25', 'Defense:50', 'Speed:35'],
        "Skills": ['Harden'],
        "ID": ['#014'],
        "Type": ['Bug', 'Poison'],
        "Others": ['Images/014.png', 'Background color: Yellow']
    },
    'Beedrill': {
        "Status": ['HP:65', 'Attack:90', 'Defense:40', 'Speed:75'],
        "Skills": ['Fury Attack', 'Twinneedle', 'Poison Jab'],
        "ID": ['#015'],
        "Type": ['Bug', 'Poison'],
        "Others": ['Images/015.png', 'Background color: Black & Yellow']
    },
    'Pidgey': {
        "Status": ['HP:40', 'Attack:45', 'Defense:40', 'Speed:56'],
        "Skills": ['Tackle', 'Gust', 'Quick Attack'],
        "ID": ['#016'],
        "Type": ['Normal', 'Flying'],
        "Others": ['Images/016.png', 'Background color: Brown']
    },
    'Pidgeotto': {
        "Status": ['HP:65', 'Attack:90', 'Defense:40', 'Speed:75'],
        "Skills": ['Wing Attack', 'Gust', 'Feather Dance'],
        "ID": ['#017'],
        "Type": ['Normal', 'Flying'],
        "Others": ['Images/017.png', 'Background color: Dark Brown']
    },
    'Pidgeot': {
        "Status": ['HP:83', 'Attack:80', 'Defense:75', 'Speed:101'],
        "Skills": ['Keen Eye', 'Tangled Feet', 'Big Pecks'],
        "ID": ['#018'],
        "Type": ['Normal', 'Flying'],
        "Others": ['Images/018.png', 'Background color: Beige']
    },
    'Rattata': {
        "Status": ['HP:30', 'Attack:56', 'Defense:35', 'Speed:72'],
        "Skills": ['Run Away', 'Guts', 'Hustle'],
        "ID": ['#019'],
        "Type": ['Normal'],
        "Others": ['Images/019.png', 'Background color: Purple']
    },
    'Raticate': {
        "Status": ['HP:55', 'Attack:81', 'Defense:60', 'Speed:97'],
        "Skills": ['Run Away', 'Guts', 'Hustle'],
        "ID": ['#020'],
        "Type": ['Normal'],
        "Others": ['Images/020.png', 'Background color: Brown']
    },
    'Spearow': {
        "Status": ['HP:40', 'Attack:60', 'Defense:30', 'Speed:70'],
        "Skills": ['Keen Eye', 'Sniper'],
        "ID": ['#021'],
        "Type": ['Normal', 'Flying'],
        "Others": ['Images/021.png', 'Background color: Brown']
    },
    'Fearow': {
        "Status": ['HP:65', 'Attack:90', 'Defense:65', 'Speed:100'],
        "Skills": ['Keen Eye', 'Sniper'],
        "ID": ['#022'],
        "Type": ['Normal', 'Flying'],
        "Others": ['Images/022.png', 'Background color: Brown']
    },
    'Ekans': {
        "Status": ['HP:35', 'Attack:60', 'Defense:44', 'Speed:55'],
        "Skills": ['Intimidate', 'Shed Skin', 'Unnerve'],
        "ID": ['#023'],
        "Type": ['Poison'],
        "Others": ['Images/023.png', 'Background color: Purple']
    },
    'Arbok': {
        "Status": ['HP:60', 'Attack:95', 'Defense:69', 'Speed:80'],
        "Skills": ['Intimidate', 'Shed Skin', 'Unnerve'],
        "ID": ['#024'],
        "Type": ['Poison'],
        "Others": ['Images/024.png', 'Background color: Purple']
    },
    'Pikachu': {
        "Status": ['HP:35', 'Attack:55', 'Defense:40', 'Speed:90'],
        "Skills": ['Static', 'Lightning Rod'],
        "ID": ['#025'],
        "Type": ['Electric'],
        "Others": ['Images/025.png', 'Background color: Yellow']
    },
    'Raichu': {
        "Status": ['HP:60', 'Attack:85', 'Defense:50', 'Speed:110'],
        "Skills": ['Static', 'Lightning Rod'],
        "ID": ['#026'],
        "Type": ['Electric'],
        "Others": ['Images/026.png', 'Background color: Orange']
    },
    'Sandshrew': {
        "Status": ['HP:50', 'Attack:75', 'Defense:85', 'Speed:40'],
        "Skills": ['Sand Veil', 'Sand Rush'],
        "ID": ['#027'],
        "Type": ['Ground'],
        "Others": ['Images/027.png', 'Background color: Tan']
    },
    'Sandslash': {
        "Status": ['HP:75', 'Attack:100', 'Defense:110', 'Speed:65'],
        "Skills": ['Sand Veil', 'Sand Rush'],
        "ID": ['#028'],
        "Type": ['Ground'],
        "Others": ['Images/028.png', 'Background color: Dark Brown']
    },
    'Nidoran♀': {
        "Status": ['HP:55', 'Attack:47', 'Defense:52', 'Speed:41'],
        "Skills": ['Poison Point', 'Rivalry', 'Hustle'],
        "ID": ['#029'],
        "Type": ['Poison'],
        "Others": ['Images/029.png', 'Background color: Light Purple']
    },
    'Nidorina': {
        "Status": ['HP:70', 'Attack:62', 'Defense:67', 'Speed:56'],
        "Skills": ['Poison Point', 'Rivalry', 'Hustle'],
        "ID": ['#030'],
        "Type": ['Poison'],
        "Others": ['Images/030.png', 'Background color: Blue']
    },
    'Nidoqueen': {
        "Status": ['HP:90', 'Attack:92', 'Defense:87', 'Speed:76'],
        "Skills": ['Poison Point', 'Rivalry', 'Sheer Force'],
        "ID": ['#031'],
        "Type": ['Poison', 'Ground'],
        "Others": ['Images/031.png', 'Background color: Blue']
    },
    'Nidoran♂': {
        "Status": ['HP:46', 'Attack:57', 'Defense:40', 'Speed:50'],
        "Skills": ['Poison Point', 'Rivalry', 'Hustle'],
        "ID": ['#032'],
        "Type": ['Poison'],
        "Others": ['Images/032.png', 'Background color: Light Purple']
    },
    'Nidorino': {
        "Status": ['HP:61', 'Attack:72', 'Defense:57', 'Speed:65'],
        "Skills": ['Poison Point', 'Rivalry', 'Hustle'],
        "ID": ['#033'],
        "Type": ['Poison'],
        "Others": ['Images/033.png', 'Background color: Dark Purple']
    },
    'Nidoking': {
        "Status": ['HP:81', 'Attack:102', 'Defense:77', 'Speed:85'],
        "Skills": ['Poison Point', 'Rivalry', 'Sheer Force'],
        "ID": ['#034'],
        "Type": ['Poison', 'Ground'],
        "Others": ['Images/034.png', 'Background color: Purple']
    },
    'Clefairy': {
        "Status": ['HP:70', 'Attack:45', 'Defense:48', 'Speed:35'],
        "Skills": ['Cute Charm', 'Magic Guard', 'Friend Guard'],
        "ID": ['#035'],
        "Type": ['Fairy'],
        "Others": ['Images035.png', 'Background color: Pink']
    },
    'Clefable': {
        "Status": ['HP:95', 'Attack:70', 'Defense:73', 'Speed:60'],
        "Skills": ['Cute Charm', 'Magic Guard', 'Unaware'],
        "ID": ['#036'],
        "Type": ['Fairy'],
        "Others": ['Images/036.png', 'Background color: Pink']
    },
    'Vulpix': {
        "Status": ['HP:38', 'Attack:41', 'Defense:40', 'Speed:65'],
        "Skills": ['Flash Fire', 'Drought'],
        "ID": ['#037'],
        "Type": ['Fire'],
        "Others": ['Images/037.png', 'Background color: Orange']
    },
# Out:
#   Cell In[5], line 101
#     }
#      ^
# SyntaxError: incomplete input
